# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanKarthik2006/BDM-Project_notebooks/blob/main/trimmed_sales_feb_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install gdown if not already installed
# !pip install -U gdown

# Step 2: Download the CSV from Google Drive using file ID
# Your file link: https://drive.google.com/file/d/1imoGEN2csoiJ9UDk6iRP6nLizbJZ8P0S/view?usp=sharing
# File ID is: 1imoGEN2csoiJ9UDk6iRP6nLizbJZ8P0S

# !gdown --id 1imoGEN2csoiJ9UDk6iRP6nLizbJZ8P0S --output trimmed_sales_feb_2024.csv

# Step 3: Load CSV using pandas
import pandas as pd

df = pd.read_csv('trimmed_sales_feb_2024.csv')
df.head()
# Out:
# ...
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1imoGEN2csoiJ9UDk6iRP6nLizbJZ8P0S
# From (redirected): https://drive.google.com/uc?id=1imoGEN2csoiJ9UDk6iRP6nLizbJZ8P0S&confirm=t&uuid=131d7b43-c70e-4ea6-a1aa-eb23e9b4681e
# To: /content/trimmed_sales_feb_2024.csv
# 100% 111M/111M [00:02<00:00, 54.7MB/s]
#    SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0        1              6       27039        381         7       0.0
# 1        2             16       25011         61         7       0.0
# 2        5             10       32653        310         9       0.0
# 3        6             13       28663        413         8       0.0
# 4       12             17       28353        285         8       0.0
#
# ...
